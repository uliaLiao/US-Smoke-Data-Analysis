# %% [markdown]
# ### Overview ###
#
#
# + my project is to answer how does the current smoker rate change in the US from 1995 to 2010.
#
#
# + the information came from the Centers for Disease Control and Prevention (CDC). Behavioral Risk Factor Surveillance System. Atlanta, Georgia: U.S. Department of Health and Human Services, Centers for Disease Control and Prevention.
#
#
# + the data shows the percentages of people who smoke everyday, somedays, used to smoke, and never smoke, varying from states to states, from 1995 to 2010. By analyzing the data, we can know how does tobacco use changes over time. That is also what I am interested in.

# %% [markdown]
# In this project, I am going to calculate the current smoker rate by adding the percentage of people who smoke every day and smoke somedays. Then, calculate the average current smoker rate of different states in the US for the same year. Finally, plot the average current smoker rate against year in the line chart.
#
#
# + design choice:
# The information was stored as SmokeData after the read function, but the SmokeData include some redundant information. So I define a new data called CurrentSmokerData and three helper functions to store information in further analysis process.

# %% [markdown]
# 1. filter out the data of Nationwide.
# ```python
# is_nationwide(sd:SmokeData)
# filter_nation_data(losd:List[SmokeData])
# ```
#
# 2. calculate the current smoker and use CurrentSmokerData rather than SmokeData to keep the information that is necessary.
# ```python
# calculate_current_smokers(sd:SmokeData)
# get_curr_smoker_data(sd:SmokeData)
# get_curr_smoker_list(losd:List[SmokeData])
# ```
#
# 3. get a list of CurrentSmokerData for the same year and calculate the average
# ```python
# is_given_year(csd:CurrentSmokerData,year:int)
# filter_year(locsd:List[CurrentSmokerData],year:int)
# calculate_aver_for_given_year(locsd:List[CurrentSmokerData],year:int)
# calculate_aver_for_years(locsd:List[CurrentSmokerData],loy:List[int])
# ```
#
# 4. take a list CurrentSmokerData and get a list of year and a list of current smoker rate
# ```python
# get_year(locsd:List[CurrentSmokerData])
# get_smoker_data(locsd:List[CurrentSmokerData])
# ```
#
# 5. plot the graph
# ```python
# plot_current_smoker_over_year(losd:List[SmokeData])
# ```
#
# ![new%20graph%20for%20presentation.jpg](attachment:new%20graph%20for%20presentation.jpg)

# %% [markdown]
# ### the most difficult part ###
# The most difficult part is to calculate the average of a list of CurrentSmokerData, which include the data for different years, rather than one given year. So I solved this problem by writing two helper functions, one calculates the average of a given year, and the other calls the first function and calculate the average for a list of different years.

# %% [markdown]
# ### my systematic programming design skills to solve problems in the future.###
#
# 1. helper functions divide a complicated tasks into easier steps
# 2. filter out unnecessary information and only keep the useful one can simplify the process.
